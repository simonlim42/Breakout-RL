# %%
# BASE DQN
# BATCH_SIZE = 32
# GAMMA = 0.99
# EPS_START = 1.
# EPS_END = 0.1
# EPS_DECAY = 9000000
# TARGET_UPDATE = 20000
# NUM_STEPS = 15000000
# M_SIZE = 1000000
# POLICY_UPDATE = 4
# EVALUATE_FREQ = 20000
# NUM_EPISODE = 100000
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('dqn.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        averageQ.append(row[5])
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

num_episodes = []
av_reward = []
average_Q=[]
epsilons=[]
maxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    av_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    num_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    epsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    maxvals.append(float(j))
    
for j in averageQ:
    j = re.sub(r'[^0-9.]', '', j)
    average_Q.append(float(j))
    
plt.plot(num_episodes, av_reward)

plt.scatter(num_episodes,av_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

plt.plot(num_episodes, maxvals)
plt.scatter(num_episodes,maxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()


plt.plot(num_episodes, average_Q)

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

# %%
# BASE DQN
# BATCH_SIZE = 32
# GAMMA = 0.99
# EPS_START = 1.
# EPS_END = 0.1
# EPS_DECAY = 9000000
# TARGET_UPDATE = 10000
# NUM_STEPS = 15000000
# M_SIZE = 1000000
# POLICY_UPDATE = 4
# EVALUATE_FREQ = 200000
# NUM_EPISODE = 100000
import matplotlib.pyplot as plt
import re 

#EVAL FREQ 20000
#EPS 9M
episodes2 = []
rewards2 = []
averageQ2=[]
maxval2=[]
epsilon2=[]
with open('DQN EPS 9M.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        maxval2.append(row[4])
        epsilon2.append(row[3])
        episodes2.append(row[1])
        rewards2.append(row[0])

num_episodes2 = []
av_reward2 = []
average_Q2=[]
epsilons2=[]
maxvals2=[]
for i in rewards2:
    i = re.sub(r'[^0-9.]', '', i)
    av_reward2.append(float(i))

for j in episodes2:
    j = re.sub(r'[^0-9.]', '', j)
    num_episodes2.append(float(j))
   
for j in epsilon2:
    j = re.sub(r'[^0-9.]', '', j)
    epsilons2.append(float(j))
    
for j in maxval2:
    j = re.sub(r'[^0-9.]', '', j)
    maxvals2.append(float(j))

plt.plot(num_episodes2, av_reward2)

# plt.scatter(num_episodes2,av_reward2,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

plt.plot(num_episodes2, maxvals2)
# plt.scatter(num_episodes2,maxvals2,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

# %%
# BASE DQN
# BATCH_SIZE = 32
# GAMMA = 0.99
# EPS_START = 1.
# EPS_END = 0.1
# EPS_DECAY = 9000000
# TARGET_UPDATE = 10000
# NUM_STEPS = 15000000
# M_SIZE = 1000000
# POLICY_UPDATE = 4
# EVALUATE_FREQ = 200000
# NUM_EPISODE = 100000
# optimizer = optim.Adam(policy_net.parameters(), lr=0.0000625, eps=1.5e-4)
import matplotlib.pyplot as plt
import re 

episodes3 = []
rewards3 = []
averageQ3=[]
maxval3=[]
epsilon3=[]
with open('DQN Eps 9M 200k eval.txt', 'r') as f:
    for text in f:
        
        row = text.split(', ')
        maxval3.append(row[4])
        epsilon3.append(row[3])
        episodes3.append(row[1])
        rewards3.append(row[0])

num_episodes3 = []
av_reward3 = []
average_Q3=[]
epsilons3=[]
maxvals3=[]
for i in rewards3:
    i = re.sub(r'[^0-9.]', '', i)
    av_reward3.append(float(i))

for j in episodes3:
    j = re.sub(r'[^0-9.]', '', j)
    num_episodes3.append(float(j))
   
for j in epsilon3:
    j = re.sub(r'[^0-9.]', '', j)
    epsilons3.append(float(j))
    
for j in maxval3:
    j = re.sub(r'[^0-9.]', '', j)
    maxvals3.append(float(j))

plt.plot(num_episodes3, av_reward3)

plt.scatter(num_episodes3,av_reward3,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

plt.plot(num_episodes3, maxvals3)
# plt.scatter(num_episodes2,maxvals2,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQNAgent Performance', fontsize = 15)
plt.show()

# %%
av_smooth1 = gaussian_filter(av_reward, sigma=2)
av_smooth2 = gaussian_filter(av_reward2, sigma=2)
av_smooth3 = gaussian_filter(av_reward3, sigma=2)

plt.plot(num_episodes, av_smooth1,label='200k eval steps,1M decay,10k update')
# plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(num_episodes2, av_smooth2,label='20k eval steps,9M decay,40k update')
# plt.scatter(num_episodes2, av_reward2,sizes=[10])
plt.plot(num_episodes3, av_smooth3,label='200k eval steps,9M decay,10k update')
# plt.scatter(num_episodes3, av_reward3,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN hyperparamaters comparison', fontsize = 15)
plt.legend()
plt.show()


plt.plot(num_episodes, average_Q,label='200k eval freq,1M decay,10k update')
# plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(num_episodes2,maxvals2,label='20k eval freq,9M decay,40k update')
# plt.scatter(num_episodes2,maxvals2,sizes=[10])
plt.plot(num_episodes3,maxvals3,label='200k eval freq,9M decay,10k update')
# plt.scatter(num_episodes3,maxvals3,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN hyperparameters comparison', fontsize = 15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('Double_DQN2.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        averageQ.append(row[5])
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

doublenum_episodes = []
doubleav_reward = []
doubleaverage_Q=[]
doubleepsilons=[]
doublemaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    doubleav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    doublenum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    doubleepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    doublemaxvals.append(float(j))
    
for j in averageQ:
    j = re.sub(r'[^0-9.]', '', j)
    doubleaverage_Q.append(float(j))
    
plt.plot(doublenum_episodes, doubleav_reward)

plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('Double-DQN Agent Performance', fontsize = 15)
plt.savefig('DoubleDQNreward.png')
plt.show()


plt.plot(doublenum_episodes, doublemaxvals)
plt.scatter(doublenum_episodes,doublemaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('Double-DQN Agent Performance', fontsize = 15)
plt.show()
plt.savefig('DoubleDQNmaxreward.png')


plt.plot(doublenum_episodes, doubleaverage_Q)
plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('Double-DQN Agent Performance', fontsize = 15)
plt.show()
plt.savefig('DoubleDQNQ.png')

# %%
plt.plot(num_episodes, av_reward,label='DQN')
plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(doublenum_episodes, doubleav_reward,label='Double DQN')
plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN vs Double-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()


plt.plot(num_episodes, maxvals,label='DQN')
plt.scatter(num_episodes,maxvals,sizes=[10])
plt.plot(doublenum_episodes, doublemaxvals,label='Double DQN')
plt.scatter(doublenum_episodes,doublemaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs Double-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()




plt.plot(num_episodes, average_Q,label='DQN')
plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(doublenum_episodes, doubleaverage_Q,label='Double DQN')
plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs Double-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('DuellingDQN.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        averageQ.append(row[5])
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

duellingnum_episodes = []
duellingav_reward = []
duellingaverage_Q=[]
duellingepsilons=[]
duellingmaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    duellingav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    duellingnum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    duellingepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    duellingmaxvals.append(float(j))
    
for j in averageQ:
    j = re.sub(r'[^0-9.]', '', j)
    duellingaverage_Q.append(float(j))
    
plt.plot(duellingnum_episodes, duellingav_reward)

plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('duelling-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(duellingnum_episodes, duellingmaxvals)
plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('duelling-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(duellingnum_episodes, duellingaverage_Q)
plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('duelling-DQN Agent Performance', fontsize = 15)
plt.show()

# %%
plt.plot(num_episodes, av_reward,label='DQN')
plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(duellingnum_episodes, duellingav_reward,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()


plt.plot(num_episodes, maxvals,label='DQN')
plt.scatter(num_episodes,maxvals,sizes=[10])
plt.plot(duellingnum_episodes, duellingmaxvals,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()



plt.plot(num_episodes, average_Q,label='DQN')
plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(duellingnum_episodes, duellingaverage_Q,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()

# %%
plt.plot(doublenum_episodes, doubleav_reward,label='Double DQN')
plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.plot(duellingnum_episodes, duellingav_reward,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('Double-DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()


plt.plot(doublenum_episodes, doublemaxvals,label='Double DQN')
plt.scatter(doublenum_episodes,doublemaxvals,sizes=[10])
plt.plot(duellingnum_episodes, duellingmaxvals,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('Double-DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()




plt.plot(doublenum_episodes, doubleaverage_Q,label='Double DQN')
plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.plot(duellingnum_episodes, duellingaverage_Q,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('Double-DQN vs duelling-DQN Agent Performance', fontsize = 15)
plt.legend()
plt.show()

# %%
from scipy.ndimage import gaussian_filter
av_smooth1 = gaussian_filter(av_reward, sigma=2)
print(len(av_reward))
print(len(av_reward[-11:]))
print(sum(av_reward[-11:])/11)
av_smooth2 = gaussian_filter(doubleav_reward, sigma=2)
av_smooth3 = gaussian_filter(duellingav_reward, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double Agent Performance', fontsize = 15)
plt.legend()
plt.show()


plt.plot(num_episodes, maxvals,label='DQN')
# plt.scatter(num_episodes,maxvals,sizes=[10])
plt.plot(doublenum_episodes, doublemaxvals,label='Double DQN')
plt.scatter(doublenum_episodes,doublemaxvals,sizes=[10])
plt.plot(duellingnum_episodes, duellingmaxvals,label='duelling DQN')
plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double Agent Performance', fontsize = 15)
plt.legend()
plt.show()



av_smoothQ1 = gaussian_filter(average_Q, sigma=2)
av_smoothQ2 = gaussian_filter(doubleaverage_Q, sigma=2)
av_smoothQ3 = gaussian_filter(duellingaverage_Q, sigma=2)
plt.plot(num_episodes, av_smoothQ1,label='DQN')
# plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(doublenum_episodes, av_smoothQ2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.plot(duellingnum_episodes,av_smoothQ3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double Agent Performance', fontsize = 15)
plt.legend()
plt.show()
# Out:
# 51
# 11
# 23.072727272727267

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('DOUBLEDUEL.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        averageQ.append(row[5])
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

doubleduellingnum_episodes = []
doubleduellingav_reward = []
doubleduellingaverage_Q=[]
doubleduellingepsilons=[]
doubleduellingmaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    doubleduellingav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    doubleduellingnum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    doubleduellingepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    doubleduellingmaxvals.append(float(j))
    
for j in averageQ:
    j = re.sub(r'[^0-9.]', '', j)
    doubleduellingaverage_Q.append(float(j))
    
plt.plot(doubleduellingnum_episodes, doubleduellingav_reward)

plt.scatter(doubleduellingnum_episodes,doubleduellingav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('doubleduelling-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(doubleduellingnum_episodes, doubleduellingmaxvals)
plt.scatter(doubleduellingnum_episodes,doubleduellingmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('doubleduelling-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(doubleduellingnum_episodes, doubleduellingaverage_Q)
plt.scatter(doubleduellingnum_episodes,doubleduellingaverage_Q,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('doubleduelling-DQN Agent Performance', fontsize = 15)
plt.show()

# %%
from scipy.ndimage import gaussian_filter
av_smooth1 = gaussian_filter(av_reward, sigma=2)
av_smooth2 = gaussian_filter(doubleav_reward, sigma=2)
av_smooth3 = gaussian_filter(duellingav_reward, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingav_reward, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.plot(doubleduellingnum_episodes, av_smooth4,label='doubleduelling DQN')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double vs Double Duelling Agent Performance', fontsize = 15)
plt.legend()
plt.show()

av_smooth1 = gaussian_filter(maxvals, sigma=2)
av_smooth2 = gaussian_filter(doublemaxvals, sigma=2)
av_smooth3 = gaussian_filter(duellingmaxvals, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingmaxvals, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_smooth1,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doublemaxva,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smooth4,label='doubleduelling DQN')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double vs Double Duelling Agent Performance', fontsize = 15)
plt.legend()
plt.show()



av_smoothQ1 = gaussian_filter(average_Q, sigma=2)
av_smoothQ2 = gaussian_filter(doubleaverage_Q, sigma=2)
av_smoothQ3 = gaussian_filter(duellingaverage_Q, sigma=2)
av_smoothQ4 = gaussian_filter(doubleduellingaverage_Q, sigma=2)
plt.plot(num_episodes, av_smoothQ1,label='DQN')
# plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(doublenum_episodes, av_smoothQ2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.plot(duellingnum_episodes,av_smoothQ3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smoothQ4,label='doubleduelling DQN')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double vs Double Duelling Agent Performance', fontsize = 15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('randomPlay.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

randomnum_episodes = []
randomav_reward = []
randomaverage_Q=[]
randomepsilons=[]
randommaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    randomav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    randomnum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    randomepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    randommaxvals.append(float(j))
    
plt.plot(randomnum_episodes, randomav_reward)

plt.scatter(randomnum_episodes,randomav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('random-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(randomnum_episodes, randommaxvals)
plt.scatter(randomnum_episodes,randommaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('random-DQN Agent Performance', fontsize = 15)
plt.show()

# %%
from scipy.ndimage import gaussian_filter

print(av_reward[-21:])
print(sum(av_reward[-21:])/21)
print(sum(doubleav_reward[-21:])/21)
print(sum(duellingav_reward[-21:])/21)
print(sum(doubleduellingav_reward[-21:])/21)
av_smooth1 = gaussian_filter(av_reward, sigma=2)
av_smooth2 = gaussian_filter(doubleav_reward, sigma=2)
av_smooth3 = gaussian_filter(duellingav_reward, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingav_reward, sigma=2)
av_smooth5 = gaussian_filter(randomav_reward, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='Dueling DQN')
# plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.plot(doubleduellingnum_episodes, av_smooth4,label='Double-Dueling DQN')
plt.plot(randomnum_episodes, av_smooth5,label='random')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('DQN vs Double DQN vs Dueling DQN vs Double-Dueling DQN vs Random', fontsize = 15)
plt.legend()
plt.show()

av_smooth1 = gaussian_filter(maxvals, sigma=2)
av_smooth2 = gaussian_filter(doublemaxvals, sigma=2)
av_smooth3 = gaussian_filter(duellingmaxvals, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingmaxvals, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_smooth1,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doublemaxva,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smooth4,label='random')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs Double DQN vs Dueling DQN vs Double-Dueling DQN vs Random', fontsize = 15)
plt.legend()
plt.show()



av_smoothQ1 = gaussian_filter(average_Q, sigma=2)
av_smoothQ2 = gaussian_filter(doubleaverage_Q, sigma=2)
av_smoothQ3 = gaussian_filter(duellingaverage_Q, sigma=2)
av_smoothQ4 = gaussian_filter(doubleduellingaverage_Q, sigma=2)
plt.plot(num_episodes, av_smoothQ1,label='DQN')
# plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(doublenum_episodes, av_smoothQ2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.plot(duellingnum_episodes,av_smoothQ3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smoothQ4,label='doubleduelling DQN')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double-DQN vs Double Duelling Agent Performance', fontsize = 15)
plt.legend()
plt.show()
# Out:
# [22.266667, 28.533333, 21.866667, 27.4, 21.066667, 25.666667, 24.4, 24.533333, 23.6, 25.4, 18.533333, 22.6, 24.0, 23.2, 25.866667, 22.0, 20.0, 25.2, 23.2, 26.0, 23.2]
# 23.73968257142857
# 24.78730152380952
# 22.809523809523814
# 23.625396857142864

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('Final RL Inter 1.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

finalRLnum_episodes = []
finalRLav_reward = []
finalRLaverage_Q=[]
finalRLepsilons=[]
finalRLmaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    finalRLav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    finalRLnum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    finalRLepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    finalRLmaxvals.append(float(j))
    
plt.plot(finalRLnum_episodes, finalRLav_reward)

plt.scatter(finalRLnum_episodes,finalRLav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('finalRL-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(finalRLnum_episodes, finalRLmaxvals)
plt.scatter(finalRLnum_episodes,finalRLmaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('finalRL-DQN Agent Performance', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import re 

episodes = []
rewards = []
averageQ=[]
maxval=[]
epsilon=[]
with open('Prio replay.txt', 'r') as f:
    for text in f:
        row = text.split(', ')
        maxval.append(row[4])
        epsilon.append(row[3])
        episodes.append(row[1])
        rewards.append(row[0])

prionum_episodes = []
prioav_reward = []
prioaverage_Q=[]
prioepsilons=[]
priomaxvals=[]
for i in rewards:
    i = re.sub(r'[^0-9.]', '', i)
    prioav_reward.append(float(i))

for j in episodes:
    j = re.sub(r'[^0-9.]', '', j)
    prionum_episodes.append(float(j))
   
for j in epsilon:
    j = re.sub(r'[^0-9.]', '', j)
    prioepsilons.append(float(j))
    
for j in maxval:
    j = re.sub(r'[^0-9.]', '', j)
    priomaxvals.append(float(j))
    
plt.plot(prionum_episodes, prioav_reward)

plt.scatter(prionum_episodes,prioav_reward,sizes=[10])

plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average reward', fontsize = 12)
plt.title('prio-DQN Agent Performance', fontsize = 15)
plt.show()


plt.plot(prionum_episodes, priomaxvals)
plt.scatter(prionum_episodes,priomaxvals,sizes=[10])
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max reward', fontsize = 12)
plt.title('prio-DQN Agent Performance', fontsize = 15)
plt.show()

# %%
from scipy.ndimage import gaussian_filter

# print(av_reward[-21:])
# print(sum(av_reward[-21:])/21)
# print(sum(doubleav_reward[-21:])/21)
# print(sum(duellingav_reward[-21:])/21)
# print(sum(doubleduellingav_reward[-21:])/21)
av_smooth1 = gaussian_filter(av_reward, sigma=2)
av_smooth2 = gaussian_filter(doubleav_reward, sigma=2)
av_smooth3 = gaussian_filter(duellingav_reward, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingav_reward, sigma=2)
av_smooth5 = gaussian_filter(randomav_reward, sigma=2)
av_smooth6 = gaussian_filter(prioav_reward, sigma=2)
av_smooth7 = gaussian_filter(finalRLav_reward, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_reward,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleav_reward,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='Dueling DQN')
# plt.scatter(duellingnum_episodes,duellingav_reward,sizes=[10])
plt.plot(doubleduellingnum_episodes, av_smooth4,label='Double-Dueling DQN')
plt.plot(randomnum_episodes, av_smooth5,label='random')
plt.plot(prionum_episodes, av_smooth6,label='Prio replay.')
plt.plot(finalRLnum_episodes, av_smooth7,label='Double,Duelling & Prio.')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average rewards', fontsize = 12)
plt.title('Comparison of different algorithms', fontsize = 15)
plt.legend()
plt.show()

av_smooth1 = gaussian_filter(maxvals, sigma=2)
av_smooth2 = gaussian_filter(doublemaxvals, sigma=2)
av_smooth3 = gaussian_filter(duellingmaxvals, sigma=2)
av_smooth4 = gaussian_filter(doubleduellingmaxvals, sigma=2)
plt.plot(num_episodes, av_smooth1,label='DQN')
# plt.scatter(num_episodes,av_smooth1,sizes=[10])
plt.plot(doublenum_episodes, av_smooth2,label='Double DQN')
# plt.scatter(doublenum_episodes,doublemaxva,sizes=[10])
plt.plot(duellingnum_episodes, av_smooth3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingmaxvals,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smooth4,label='random')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Max vals', fontsize = 12)
plt.title('DQN vs Double DQN vs Dueling DQN vs Double-Dueling DQN vs Random', fontsize = 15)
plt.legend()
plt.show()



av_smoothQ1 = gaussian_filter(average_Q, sigma=2)
av_smoothQ2 = gaussian_filter(doubleaverage_Q, sigma=2)
av_smoothQ3 = gaussian_filter(duellingaverage_Q, sigma=2)
av_smoothQ4 = gaussian_filter(doubleduellingaverage_Q, sigma=2)
plt.plot(num_episodes, av_smoothQ1,label='DQN')
# plt.scatter(num_episodes,average_Q,sizes=[10])
plt.plot(doublenum_episodes, av_smoothQ2,label='Double DQN')
# plt.scatter(doublenum_episodes,doubleaverage_Q,sizes=[10])
plt.plot(duellingnum_episodes,av_smoothQ3,label='duelling DQN')
# plt.scatter(duellingnum_episodes,duellingaverage_Q,sizes=[10])
plt.plot(doubleduellingnum_episodes,av_smoothQ4,label='doubleduelling DQN')
plt.xlabel('Number of steps', fontsize = 12)
plt.ylabel('Average Q', fontsize = 12)
plt.title('DQN vs duelling-DQN vs Double-DQN vs Double Duelling Agent Performance', fontsize = 15)
plt.legend()
plt.show()
